# %% [markdown]
# ---
# comments: false
# layout: post
# title: Study Blog
# ---

# %% [markdown]
# # Areas I've Identified for Improvement (Based on Practice MCQs)
# - 3.11 Binary Search: 50% correct
# - 3.17 Algorithmic Efficiency: 60% correct
# - 3.18 Undecidable Problems: 67% correct
# - 5.2 Digital Divide: 67% correct
# - 5.3 Computing Bias: 0% correct
#
# ![](/alex_2025/images/notebooks/foundation/mcqweak.png)
#
# # How I'm Addressing These Gaps
# Key takeaways from videos
#
# ## 3.11 Binary Search – Daily Video 1
# - Understands how binary search splits a sorted list in half repeatedly
# - Compares the middle item to the target
# - Efficient for large datasets (logarithmic time)
# - Only works on sorted lists
#
# ![](/alex_2025/images/notebooks/foundation/binsearch.png)
#
# ## 3.17 Algorithmic Efficiency - Daily Video 1 & 2
# - Measures efficiency using time complexity (Big O)
# - Reasonable vs. unreasonable runtimes (e.g. linear vs. exponential)
# - Impacts scalability of programs
# - Heuristics: useful when exact solutions are impractical
# - Sacrifices precision for speed
# - Common in optimization and AI problems
#
# ![](/alex_2025/images/notebooks/foundation/reason.png)
#
# ## 3.18 Undecidable Problems – Daily Video 1
# - Some problems have no algorithmic solution
# - The Halting Problem: famous example
# - Recognize the limits of computation
# - Not all problems are solvable by code
#
# ![](/alex_2025/images/notebooks/foundation/halting.png)
#
# ## 5.2 Digital Divide – Daily Video 1
# - Gap in access to technology and the internet
# - Affects education, job opportunities, civic participation
# - Often linked to income, geography, age
#
# ![](/alex_2025/images/notebooks/foundation/divide.png)
#
# ## 5.3 Computing Bias – Daily Video 1
# - Algorithms can reinforce human biases
# - Training data matters
# - Bias in AI can lead to unfair outcomes
# - Need for fairness and transparency in computing
#
# ![](/alex_2025/images/notebooks/foundation/bias.png)
#
# # Additional Resources I’ve Used to Strengthen My Understanding
# ## Binary Search
# - [Khan Academy – Step-by-step breakdowns and explanations](https://www.khanacademy.org/computing/computer-science/algorithms/binary-search/a/binary-search)
# - [Binary Search in 100 secs Video (Fireship) – Visual demo of lists being searched](https://www.youtube.com/watch?v=MFhxShGxHWc)
# - [GeeksforGeeks – Practice problems and concept explanations](https://www.geeksforgeeks.org/problems/binary-search-1587115620/1)
#
# ## Algorithmic Efficiency
# - [Khan Academy – Teaches Big O clearly](https://www.khanacademy.org/computing/computer-science/algorithms/asymptotic-notation/a/big-o-notation)
# - [Big O Cheatsheet – Easy reference for runtimes](https://www.bigocheatsheet.com/)
# - [VisuAlgo – Interactive animations of algorithm runtimes](https://visualgo.net/en/sorting?slide=1)
#
# ## Undecidable Problems
# - [Computerphile – Halting Problem – Explains why some problems can’t be solved](https://www.youtube.com/watch?v=macM_MtS_w4)
# - [VisualGo Graphs – Great for understanding problem-solving limits](https://visualgo.net/en/graphds?slide=1)
# - [TSPVis Simulation – Shows difficulty of optimization problems](https://tspvis.com/)
#
# ## Digital Divide
# - [Pew Research Center Reports – Real data on access disparities](https://www.pewresearch.org/topic/internet-technology/technology-policy-issues/digital-divide/)
# - [Digital Divide Council – Articles and case studies](http://www.digitaldividecouncil.com/)
# - [National Digital Inclusion Alliance – Focus on equity in access](https://www.digitalinclusion.org/)
#
# ## Computing Bias
# - [Google What-If Tool – Visualizes how models behave](https://pair-code.github.io/what-if-tool/)
# - [IBM AI Fairness 360 – Toolkit for checking fairness](https://research.ibm.com/blog/ai-fairness-360)
# - [MIT Moral Machine – Public input on ethical AI decisions](https://www.moralmachine.net/)
#
# # Summary
# I've used my MCQ results to pinpoint weak areas and focused on them using College Board videos and external tools. These resources have helped me build a deeper understanding and prepare for the AP exam more effectively.
#
# # [Self Grade](https://github.com/alexgstf/alex_2025/issues/16)
